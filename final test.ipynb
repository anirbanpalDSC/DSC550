# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

df = pd.read_json('categorized-comments.jsonl', lines=True)

# Create test and train datasets
df = df.head(n=500)

df['id'] = df.index + 1

df.dropna(axis=0)

df.set_index('id', inplace = True)

msk = np.random.rand(len(df)) < 0.75

train = df[msk]

test = df[~msk]

train.head()
# Out:
#        cat                                                txt
# id
# 1   sports  Barely better than Gabbert? He was significant...
# 2   sports  Fuck the ducks and the Angels! But welcome to ...
# 3   sports  Should have drafted more WRs.\n\n- Matt Millen...
# 4   sports            [Done](https://i.imgur.com/2YZ90pm.jpg)
# 6   sports  Ding dong the Kaepers gone!!!!!! Yes!!!! Frida...

# %%
df = train

# %%
import re
from nltk.corpus import stopwords

stopWords = set(stopwords.words('english'))

#creating a function to encapsulate preprocessing, to mkae it easy to replicate on  submission data
def processing(df):
    #lowering and removing punctuation
    df['processed'] = df['txt'].apply(lambda x: re.sub(r'[^\w\s]','', x.lower()))
    
    #numerical feature engineering
    #total length of sentence
    df['length'] = df['processed'].apply(lambda x: len(x))
    #get number of words
    df['words'] = df['processed'].apply(lambda x: len(x.split(' ')))
    df['words_not_stopword'] = df['processed'].apply(lambda x: len([t for t in x.split(' ') if t not in stopWords]))
    #get the average word length
    df['avg_word_length'] = df['processed'].apply(lambda x: np.mean([len(t) for t in x.split(' ') if t not in stopWords]) if len([len(t) for t in x.split(' ') if t not in stopWords]) > 0 else 0)
    #get the average word length
    df['commas'] = df['txt'].apply(lambda x: x.count(','))

    return(df)

df = processing(df)

df.head()
# Out:
#        cat                                                txt  \
# id
# 1   sports  Barely better than Gabbert? He was significant...
# 2   sports  Fuck the ducks and the Angels! But welcome to ...
# 3   sports  Should have drafted more WRs.\n\n- Matt Millen...
# 4   sports            [Done](https://i.imgur.com/2YZ90pm.jpg)
# 6   sports  Ding dong the Kaepers gone!!!!!! Yes!!!! Frida...
#
#                                             processed  length  words  \
# id
# 1   barely better than gabbert he was significantl...     505     94
# 2   fuck the ducks and the angels but welcome to a...      64     13
# 3   should have drafted more wrs\n\n matt millen p...      51      8
# 4                        donehttpsiimgurcom2yz90pmjpg      28      1
# 6   ding dong the kaepers gone yes friday off to a...      57     12
#
#     words_not_stopword  avg_word_length  commas
# id
# 1                   55         5.327273       8
# 2                    7         5.000000       0
# 3                    5         6.000000       0
# 4                    1        28.000000       0
# 6                    8         4.625000       0

# %%
from sklearn.model_selection import train_test_split

features= [c for c in df.columns.values if c  not in ['id','txt','cat']]
numeric_features= [c for c in df.columns.values if c  not in ['id','txt','cat','processed']]
target = 'cat'

X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.33, random_state=42)
X_train.head()
# Out:
#                                              processed  length  words  \
# id
# 390                      anybody drink craft beer here      29      5
# 162  jennifer joe honey can you take out the garbag...     218     40
# 42   they asked him to prove it and he didnt live u...     479     95
# 47   third firstround dl in three years  seems a bi...     114     20
# 216  he can be undecided all he likes dont see anyw...     165     37
#
#      words_not_stopword  avg_word_length  commas
# id
# 390                   4         5.250000       0
# 162                  22         5.863636       3
# 42                   52         5.250000       1
# 47                   15         5.666667       0
# 216                  17         4.352941       1

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class TextSelector(BaseEstimator, TransformerMixin):
    """
    Transformer to select a single column from the data frame to perform additional transformations on
    Use on text columns in the data
    """
    def __init__(self, key):
        self.key = key

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X[self.key]
    
class NumberSelector(BaseEstimator, TransformerMixin):
    """
    Transformer to select a single column from the data frame to perform additional transformations on
    Use on numeric columns in the data
    """
    def __init__(self, key):
        self.key = key

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X[[self.key]]

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle

# Dump the trained decision tree classifier with Pickle
tfidf_model_file = 'TfidfVectorizer.pkl'

# Open the file to save as pkl file
tfidf_model_pkl = open(tfidf_model_file, 'wb')

text = Pipeline([
                ('selector', TextSelector(key='processed')),
                ('tfidf', TfidfVectorizer( stop_words='english'))
            ])

tfidf_model = text.fit_transform(X_train)
pickle.dump(tfidf_model, tfidf_model_pkl)
tfidf_model
# Out:
# <243x1504 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2865 stored elements in Compressed Sparse Row format>

# %%
from sklearn.preprocessing import StandardScaler

length =  Pipeline([
                ('selector', NumberSelector(key='length')),
                ('standard', StandardScaler())
            ])

length.fit_transform(X_train)
# Out:
# array([[-6.87409694e-01],
#        [ 4.71529589e-01],
#        [ 2.07196955e+00],
#        [-1.66193614e-01],
#        [ 1.46536034e-01],
#        [-3.62416138e-01],
#        [-7.30333371e-01],
#        [-7.30333371e-01],
#        [ 7.29071652e-01],
#        [-3.93075908e-01],
#        [ 2.09036541e+00],
#        [-1.66193614e-01],
#        [ 2.36017138e+00],
#        [-4.11471769e-01],
#        [-4.35545366e-02],
#        [-3.99207861e-01],
#        [-4.97319123e-01],
#        [-6.75145786e-01],
#        [ 5.38981082e-01],
#        [-5.58638662e-01],
#        [-6.01562339e-01],
#        [ 2.12102518e+00],
#        [ 2.17008081e+00],
#        [-3.50152230e-01],
#        [-4.72791308e-01],
#        [ 3.00289099e-02],
#        [-3.86943954e-01],
#        [-6.87409694e-01],
#        [ 7.90391191e-01],
#        [ 1.77763576e+00],
#        [ 5.45567254e-02],
#        [-1.29401891e-01],
#        [-8.22312679e-01],
#        [ 9.55953945e-01],
#        [-6.13826247e-01],
#        [-2.82700738e-01],
#        [ 1.77650022e-02],
#        [-3.19492461e-01],
#        [-3.44020277e-01],
#        [-8.65236356e-01],
#        [-3.44020277e-01],
#        [-7.11937509e-01],
#        [ 1.56301738e+00],
#        [-5.46374754e-01],
#        [ 2.07855572e-01],
#        [-8.22312679e-01],
#        [ 9.25294176e-01],
#        [-7.05805555e-01],
#        [-3.99207861e-01],
#        [ 6.30960390e-01],
#        [ 7.29071652e-01],
#        [ 3.20638102e+00],
#        [-9.87421215e-02],
#        [-7.91652909e-01],
#        [-7.79389002e-01],
#        [ 2.28658794e+00],
#        [-7.05805555e-01],
#        [ 1.15876264e-01],
#        [-8.22312679e-01],
#        [ 3.12098788e-01],
#        [-8.46840494e-01],
#        [ 2.69175111e-01],
#        [-1.96853383e-01],
#        [ 2.56911203e-01],
#        [-4.85055216e-01],
#        [-3.25624415e-01],
#        [-3.25624415e-01],
#        [-2.27513153e-01],
#        [ 5.14453266e-01],
#        [ 4.96057405e-01],
#        [-8.22312679e-01],
#        [-9.87421215e-02],
#        [-8.22312679e-01],
#        [-2.27513153e-01],
#        [-4.54395446e-01],
#        [-4.85055216e-01],
#        [-1.72325568e-01],
#        [-5.52506708e-01],
#        [-6.44486016e-01],
#        [-3.01096599e-01],
#        [ 8.39446822e-01],
#        [ 1.18896819e+00],
#        [ 1.95591665e-01],
#        [ 3.67286373e-01],
#        [-6.13826247e-01],
#        [ 1.89459711e-01],
#        [-8.40708540e-01],
#        [-1.90267211e-02],
#        [ 1.03612356e-01],
#        [ 3.18230742e-01],
#        [-1.84589476e-01],
#        [ 2.75307065e-01],
#        [-8.46840494e-01],
#        [ 7.84259237e-01],
#        [-8.22312679e-01],
#        [-4.23735677e-01],
#        [-4.54395446e-01],
#        [ 7.90391191e-01],
#        [-8.22312679e-01],
#        [ 1.69792036e+00],
#        [-8.34576587e-01],
#        [-2.21381199e-01],
#        [-7.67125094e-01],
#        [ 3.97946142e-01],
#        [ 1.17057233e+00],
#        [-2.51586750e-02],
#        [-1.78457522e-01],
#        [-3.74225827e-02],
#        [ 2.28045598e+00],
#        [ 5.94168667e-01],
#        [ 1.41585049e+00],
#        [-4.85055216e-01],
#        [-4.78923262e-01],
#        [ 5.72661406e+00],
#        [-3.07228553e-01],
#        [-6.19958201e-01],
#        [-2.94964646e-01],
#        [ 6.68206332e-02],
#        [ 6.00300620e-01],
#        [ 1.03612356e-01],
#        [-6.26090155e-01],
#        [-6.69013832e-01],
#        [ 2.01723618e-01],
#        [-3.93075908e-01],
#        [-6.93541647e-01],
#        [ 1.19510015e+00],
#        [-4.78923262e-01],
#        [-8.22312679e-01],
#        [-1.28947672e-02],
#        [-6.87409694e-01],
#        [-2.52040968e-01],
#        [-7.48729232e-01],
#        [-5.34110847e-01],
#        [ 4.47001773e-01],
#        [-5.15714985e-01],
#        [ 2.23140035e+00],
#        [ 2.77714425e+00],
#        [-7.36465325e-01],
#        [-6.30859452e-04],
#        [-6.56749924e-01],
#        [-6.26090155e-01],
#        [-5.58638662e-01],
#        [-8.22312679e-01],
#        [-7.18069463e-01],
#        [ 5.75772805e-01],
#        [ 2.38969561e-02],
#        [-6.19958201e-01],
#        [-8.22312679e-01],
#        [ 1.87574703e+00],
#        [-3.50152230e-01],
#        [ 1.31160727e+00],
#        [-4.54395446e-01],
#        [-1.28947672e-02],
#        [ 6.06886793e-02],
#        [-6.26090155e-01],
#        [-4.23735677e-01],
#        [-4.42131539e-01],
#        [-8.46840494e-01],
#        [-3.68548092e-01],
#        [-6.38354063e-01],
#        [-7.18069463e-01],
#        [-8.16180725e-01],
#        [-5.27978893e-01],
#        [ 1.03612356e-01],
#        [-3.50152230e-01],
#        [ 9.37558084e-01],
#        [-1.35533845e-01],
#        [-3.56284184e-01],
#        [ 6.68206332e-02],
#        [-4.54395446e-01],
#        [-7.24201417e-01],
#        [ 1.09744310e-01],
#        [-8.22312679e-01],
#        [ 6.00300620e-01],
#        [-7.24201417e-01],
#        [-7.42597278e-01],
#        [-4.85055216e-01],
#        [-5.95430385e-01],
#        [-1.35533845e-01],
#        [ 9.55953945e-01],
#        [-2.70436830e-01],
#        [-8.46840494e-01],
#        [-8.22312679e-01],
#        [-2.94964646e-01],
#        [-7.73257048e-01],
#        [ 4.71529589e-01],
#        [-4.72791308e-01],
#        [ 2.88138746e+00],
#        [-8.59104402e-01],
#        [-8.22312679e-01],
#        [-6.38354063e-01],
#        [ 2.63043157e-01],
#        [-7.79389002e-01],
#        [-6.32222109e-01],
#        [ 2.01723618e-01],
#        [-8.03916817e-01],
#        [-4.05339815e-01],
#        [-8.34576587e-01],
#        [-6.19958201e-01],
#        [ 9.74804026e-02],
#        [-7.97784863e-01],
#        [-6.44486016e-01],
#        [-7.24201417e-01],
#        [ 5.70208625e+00],
#        [-3.80812000e-01],
#        [ 4.84247716e-02],
#        [-7.73257048e-01],
#        [ 4.65397635e-01],
#        [ 9.31426130e-01],
#        [-6.01562339e-01],
#        [ 1.37292681e+00],
#        [-4.29867631e-01],
#        [ 6.06886793e-02],
#        [-7.42143060e-02],
#        [-5.95430385e-01],
#        [-6.26090155e-01],
#        [-7.79389002e-01],
#        [-4.60527400e-01],
#        [-7.05805555e-01],
#        [-7.30333371e-01],
#        [-4.29867631e-01],
#        [ 5.50109442e-03],
#        [ 4.04078096e-01],
#        [-8.22312679e-01],
#        [ 3.96061134e+00],
#        [-3.74680046e-01],
#        [-6.80823521e-02],
#        [-8.22312679e-01],
#        [ 2.58705368e+00],
#        [-7.05805555e-01],
#        [-5.89298432e-01],
#        [-5.34110847e-01],
#        [-3.19492461e-01],
#        [ 1.13991256e+00],
#        [ 7.29071652e-01],
#        [-1.60061660e-01],
#        [-5.58638662e-01],
#        [-3.01096599e-01],
#        [-5.64770616e-01],
#        [ 6.37092344e-01],
#        [ 6.06432574e-01],
#        [ 3.48890511e-01],
#        [-4.48263492e-01]])

# %%
words =  Pipeline([
                ('selector', NumberSelector(key='words')),
                ('standard', StandardScaler())
            ])
words_not_stopword =  Pipeline([
                ('selector', NumberSelector(key='words_not_stopword')),
                ('standard', StandardScaler())
            ])
avg_word_length =  Pipeline([
                ('selector', NumberSelector(key='avg_word_length')),
                ('standard', StandardScaler())
            ])
commas =  Pipeline([
                ('selector', NumberSelector(key='commas')),
                ('standard', StandardScaler()),
            ])

# %%
from sklearn.pipeline import FeatureUnion

feats = FeatureUnion([('text', text), 
                      ('length', length),
                      ('words', words),
                      ('words_not_stopword', words_not_stopword),
                      ('avg_word_length', avg_word_length),
                      ('commas', commas)])

feature_processing = Pipeline([('feats', feats)])
feature_processing.fit_transform(X_train)
# Out:
# <243x1509 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4080 stored elements in Compressed Sparse Row format>

# %%
from sklearn.ensemble import RandomForestClassifier

pipeline = Pipeline([
    ('features',feats),
    ('classifier', RandomForestClassifier(random_state = 42)),
])

pipeline.fit(X_train, y_train)

preds = pipeline.predict(X_test)
np.mean(preds == y_test)
# Out:
# 1.0

# %%
pipeline.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'features', 'classifier', 'features__n_jobs', 'features__transformer_list', 'features__transformer_weights', 'features__text', 'features__length', 'features__words', 'features__words_not_stopword', 'features__avg_word_length', 'features__commas', 'features__text__memory', 'features__text__steps', 'features__text__selector', 'features__text__tfidf', 'features__text__selector__key', 'features__text__tfidf__analyzer', 'features__text__tfidf__binary', 'features__text__tfidf__decode_error', 'features__text__tfidf__dtype', 'features__text__tfidf__encoding', 'features__text__tfidf__input', 'features__text__tfidf__lowercase', 'features__text__tfidf__max_df', 'features__text__tfidf__max_features', 'features__text__tfidf__min_df', 'features__text__tfidf__ngram_range', 'features__text__tfidf__norm', 'features__text__tfidf__preprocessor', 'features__text__tfidf__smooth_idf', 'features__text__tfidf__stop_words', 'features__text__tfidf__strip_accents', 'features__text__tfidf__sublinear_tf', 'features__text__tfidf__token_pattern', 'features__text__tfidf__tokenizer', 'features__text__tfidf__use_idf', 'features__text__tfidf__vocabulary', 'features__length__memory', 'features__length__steps', 'features__length__selector', 'features__length__standard', 'features__length__selector__key', 'features__length__standard__copy', 'features__length__standard__with_mean', 'features__length__standard__with_std', 'features__words__memory', 'features__words__steps', 'features__words__selector', 'features__words__standard', 'features__words__selector__key', 'features__words__standard__copy', 'features__words__standard__with_mean', 'features__words__standard__with_std', 'features__words_not_stopword__memory', 'features__words_not_stopword__steps', 'features__words_not_stopword__selector', 'features__words_not_stopword__standard', 'features__words_not_stopword__selector__key', 'features__words_not_stopword__standard__copy', 'features__words_not_stopword__standard__with_mean', 'features__words_not_stopword__standard__with_std', 'features__avg_word_length__memory', 'features__avg_word_length__steps', 'features__avg_word_length__selector', 'features__avg_word_length__standard', 'features__avg_word_length__selector__key', 'features__avg_word_length__standard__copy', 'features__avg_word_length__standard__with_mean', 'features__avg_word_length__standard__with_std', 'features__commas__memory', 'features__commas__steps', 'features__commas__selector', 'features__commas__standard', 'features__commas__selector__key', 'features__commas__standard__copy', 'features__commas__standard__with_mean', 'features__commas__standard__with_std', 'classifier__bootstrap', 'classifier__class_weight', 'classifier__criterion', 'classifier__max_depth', 'classifier__max_features', 'classifier__max_leaf_nodes', 'classifier__min_impurity_decrease', 'classifier__min_impurity_split', 'classifier__min_samples_leaf', 'classifier__min_samples_split', 'classifier__min_weight_fraction_leaf', 'classifier__n_estimators', 'classifier__n_jobs', 'classifier__oob_score', 'classifier__random_state', 'classifier__verbose', 'classifier__warm_start'])

# %%
from sklearn.model_selection import GridSearchCV

hyperparameters = { 'features__text__tfidf__max_df': [0.9, 0.95],
                    'features__text__tfidf__ngram_range': [(1,1), (1,2)],
                   'classifier__max_depth': [50, 70],
                    'classifier__min_samples_leaf': [1,2]
                  }
clf = GridSearchCV(pipeline, hyperparameters, cv=5)
 
# Fit and tune model
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('features', FeatureUnion(n_jobs=None,
#        transformer_list=[('text', Pipeline(memory=None,
#      steps=[('selector', TextSelector(key='processed')), ('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', inpu...mators=10, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'features__text__tfidf__max_df': [0.9, 0.95], 'features__text__tfidf__ngram_range': [(1, 1), (1, 2)], 'classifier__max_depth': [50, 70], 'classifier__min_samples_leaf': [1, 2]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
clf.best_params_
# Out:
# {'classifier__max_depth': 50,
#  'classifier__min_samples_leaf': 1,
#  'features__text__tfidf__max_df': 0.9,
#  'features__text__tfidf__ngram_range': (1, 1)}

# %%
#refitting on entire training data using best settings
clf.refit

preds = clf.predict(X_test)
probs = clf.predict_proba(X_test)

np.mean(preds == y_test)
# Out:
# 1.0

# %%
X_test.head()
# Out:
#                                              processed  length  words  \
# id
# 227  more the organization not the league buying th...      58      9
# 44   oh well looks like im not the only one who mis...      55     12
# 19                                             deleted       7      1
# 429  dude they shouldnt be calling any pass play in...      76     14
# 73   i know we wont be watchable next year but i at...     217     39
#
#      words_not_stopword  avg_word_length  commas
# id
# 227                   4         8.500000       0
# 44                    7         3.857143       0
# 19                    1         7.000000       0
# 429                   8         5.625000       0
# 73                   21         6.190476       1

# %%
submission = test

#preprocessing
submission = processing(submission)
predictions = clf.predict_proba(submission)

preds = pd.DataFrame(data=predictions, columns = clf.best_estimator_.named_steps['classifier'].classes_)

#generating a submission file
result = pd.concat([submission[['id']], preds], axis=1)
result.set_index('id', inplace = True)
result

# %%
data = [[1], [1], [0]] 
  
# Create the pandas DataFrame 
y = pd.DataFrame(data, columns = ['P'])

# %%
pd.concat([x[['Name']], y], axis=1)
# Out:
#    Name  P
# 0   tom  1
# 1  nick  1
# 2  juli  0

# %%
test
# Out:
#         cat                                                txt  \
# 4    sports                                      No!! NOO!!!!!
# 14   sports                                                 o/
# 16   sports                             I believe in upvotes!!
# 23   sports                                                 No
# 27   sports  I guess at this point, there's just no reason ...
# 29   sports  This is under the assumption that the reports ...
# 31   sports             Needs more filters and comic sans font
# 35   sports  Eric Berry was a higher rated prospect than ET...
# 36   sports                Thanks again Cleveland and Houston
# 40   sports  I would go after receivers who prefer to carry...
# 50   sports             ahh got me there. Point still stands.
# 60   sports  doesnt matter what hes worth, he knows qbs are...
# 65   sports                  Why do you think that's the case?
# 67   sports  And we also had one of the worst defenses in N...
# 71   sports                               Why so pessimistic?
# 73   sports  Bro we get it you like Kap and would rather se...
# 86   sports  See, i thought Darnold was only a freshman as ...
# 89   sports  Shame on them for going cheap the first time a...
# 91   sports  To be fair, that game was an absolute pile of ...
# 92   sports  &gt;The Hall of Fame class will be announced a...
# 99   sports  Schaub is worth bringing in to mentor and help...
# 103  sports  Greatest comeback of all time regardless of ou...
# 106  sports  No, it wouldn't proclude a trade, but we'd be ...
# 109  sports  Hodges and Kerley are the only ones I'd consid...
# 110  sports                                   ITS ALL OGREEEEE
# 115  sports  IDK about the Chip Kelly hiring, but I know he...
# 120  sports    Just a throw in... to balance out the salaries.
# 121  sports  That we accept. I mean it's pretty plain and s...
# 129  sports  Source? :-p if true, thats pretty relevant fro...
# 131  sports  Talk about why the fans call themselves "The F...
# ..      ...                                                ...
# 384  sports  I agree. Not only his professionalism, but his...
# 385  sports  Imagine getting Marshall and Jeffrey together....
# 391  sports  He could be, if we could stop the run and had ...
# 392  sports                             No hyperbole there. /s
# 393  sports  Rich Scangarello is a great hire and an OC who...
# 396  sports  Rashard excels at press man coverage. It is hi...
# 400  sports  Thanks for the memories, Kap. \n\nNow the real...
# 403  sports  Sense we are switching to a 4-3 we need guys w...
# 404  sports  the defense wasn't good enough to help the tea...
# 406  sports  I rly doubt that cousins goes for a 2nd and a ...
# 411  sports  I think it's fine taking a QB round 3 or 4, it...
# 413  sports  Outdated more than idiotic, but I agree, I'm v...
# 424  sports  You're a moron.  I'm blocking you.  Have a nic...
# 426  sports  Lol salty.  Let it go dude, the D blew the lead.
# 429  sports  Thanks for including this, I didn't think to a...
# 432  sports  It's called opportunity cost. Every resource y...
# 433  sports        u mfer made me laugh\nlet's get that 2000$!
# 434  sports  Kyle Shanahan loses the Super Bowl and now he'...
# 441  sports  Loved the post game interview with Kap and Bow...
# 444  sports  When I saw him with the Pom-Poms I didn't know...
# 448  sports  Just put a reasonable time limit on it and mak...
# 462  sports  I mean if we pick up Cousins at QB and maybe e...
# 464  sports  Hmm... whenever we do go and get the QB of the...
# 472  sports  What is this crazy concept of trust between th...
# 476  sports  I love Kap as a human being, and I love the me...
# 478  sports                    Eddie Murphy hasn't aged a day.
# 484  sports  Damn, after reading this I just realized that ...
# 487  sports  I think honestly, and without a doubt, that th...
# 491  sports  [Not my circus anymore.](https://imgflip.com/s...
# 497  sports                                 He's slow as fuck.
#
#                                              processed  length  words  \
# 4                                               no noo       6      2
# 14                                                   o       1      1
# 16                                i believe in upvotes      20      4
# 23                                                  no       2      1
# 27   i guess at this point theres just no reason no...     163     30
# 29   this is under the assumption that the reports ...     359     75
# 31              needs more filters and comic sans font      38      7
# 35   eric berry was a higher rated prospect than et...     383     73
# 36                 thanks again cleveland and houston       35      6
# 40   i would go after receivers who prefer to carry...      74     15
# 50                ahh got me there point still stands       36      8
# 60   doesnt matter what hes worth he knows qbs are ...     143     31
# 65                     why do you think thats the case      31      7
# 67   and we also had one of the worst defenses in n...     185     35
# 71                                 why so pessimistic       19      4
# 73   bro we get it you like kap and would rather se...     385     77
# 86   see i thought darnold was only a freshman as w...     117     26
# 89   shame on them for going cheap the first time a...     381     77
# 91   to be fair that game was an absolute pile of s...     144     29
# 92   gtthe hall of fame class will be announced at ...     258     37
# 99   schaub is worth bringing in to mentor and help...     140     27
# 103  greatest comeback of all time regardless of ou...      51      8
# 106  no it wouldnt proclude a trade but wed be very...     142     28
# 109  hodges and kerley are the only ones id conside...      55     10
# 110                                   its all ogreeeee      16      3
# 115  idk about the chip kelly hiring but i know he ...      72     15
# 120        just a throw in to balance out the salaries      43      9
# 121  that we accept i mean its pretty plain and simple      49     10
# 129  source p if true thats pretty relevant from th...      61     11
# 131  talk about why the fans call themselves the fa...      52      9
# ..                                                 ...     ...    ...
# 384  i agree not only his professionalism but his l...     113     22
# 385  imagine getting marshall and jeffrey together ...      53      7
# 391  he could be if we could stop the run and had a...     144     31
# 392                               no hyperbole there s      20      4
# 393  rich scangarello is a great hire and an oc who...      94     18
# 396  rashard excels at press man coverage it is his...      85     16
# 400  thanks for the memories kap \n\nnow the real q...      85     18
# 403  sense we are switching to a 43 we need guys wh...     150     33
# 404  the defense wasnt good enough to help the team...      67     12
# 406  i rly doubt that cousins goes for a 2nd and a ...     125     28
# 411  i think its fine taking a qb round 3 or 4 its ...     171     36
# 413  outdated more than idiotic but i agree im very...     111     23
# 424    youre a moron  im blocking you  have a nice day      47     12
# 426     lol salty  let it go dude the d blew the lead       46     13
# 429  thanks for including this i didnt think to add...      83     18
# 432  its called opportunity cost every resource you...     792    149
# 433           u mfer made me laugh\nlets get that 2000      39      8
# 434  kyle shanahan loses the super bowl and now hes...     128     24
# 441  loved the post game interview with kap and bow...     217     40
# 444  when i saw him with the pompoms i didnt know w...      58     13
# 448  just put a reasonable time limit on it and mak...     197     38
# 462  i mean if we pick up cousins at qb and maybe e...     148     30
# 464  hmm whenever we do go and get the qb of the fu...     369     78
# 472  what is this crazy concept of trust between th...      60     12
# 476  i love kap as a human being and i love the mem...     218     45
# 478                      eddie murphy hasnt aged a day      29      6
# 484  damn after reading this i just realized that t...     147     27
# 487  i think honestly and without a doubt that the ...     498    102
# 491  not my circus anymorehttpsimgflipcomsmemebutth...      68      4
# 497                                   hes slow as fuck      16      4
#
#      words_not_stopword  avg_word_length  commas
# 4                     1         3.000000       0
# 14                    0         0.000000       0
# 16                    2         7.000000       0
# 23                    0         0.000000       0
# 27                   15         6.000000       2
# 29                   35         5.057143       1
# 31                    5         5.000000       0
# 35                   43         5.418605       3
# 36                    4         5.500000       0
# 40                    8         4.875000       0
# 50                    6         3.666667       0
# 60                   18         4.500000       1
# 65                    3         4.666667       0
# 67                   19         5.526316       1
# 71                    2         5.500000       0
# 73                   45         5.000000       1
# 86                   13         4.692308       3
# 89                   41         5.024390       3
# 91                   12         5.416667       1
# 92                   21         8.571429       2
# 99                   14         5.500000       0
# 103                   5         7.400000       0
# 106                  16         5.312500       2
# 109                   6         5.500000       0
# 110                   1         8.000000       0
# 115                   9         4.555556       1
# 120                   3         6.666667       0
# 121                   5         5.400000       0
# 129                   8         5.250000       1
# 131                   4         5.000000       0
# ..                  ...              ...     ...
# 384                   9         6.444444       1
# 385                   6         7.333333       0
# 391                  14         5.142857       1
# 392                   1         9.000000       0
# 393                  11         5.545455       0
# 396                   9         5.777778       0
# 400                   9         5.000000       2
# 403                  16         4.750000       1
# 404                   9         5.333333       1
# 406                  17         4.529412       0
# 411                  19         4.789474       1
# 413                  10         5.100000       2
# 424                   8         3.375000       0
# 426                   9         2.777778       1
# 429                  10         4.500000       1
# 432                  76         5.881579       0
# 433                   6         4.333333       0
# 434                  14         5.500000       0
# 441                  23         5.869565       1
# 444                   5         4.800000       0
# 448                  20         5.450000       2
# 462                  19         5.105263       1
# 464                  43         4.837209       3
# 472                   5         4.800000       0
# 476                  19         5.315789       2
# 478                   5         4.600000       0
# 484                  14         5.357143       1
# 487                  49         5.224490       7
# 491                   2        30.000000       0
# 497                   3         3.666667       0
#
# [137 rows x 8 columns]
